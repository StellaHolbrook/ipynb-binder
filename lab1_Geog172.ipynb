# %% [markdown]
# ###Hey! this is my first Geog 172 lab!

# %% [markdown]
# Begin by reading in the data file, we will specifically need the pandas and numpy libraries to read in these files effectivly.

# %%
import numpy as np
import pandas as pd

# %%
ithaca_data = pd.read_csv("ithaca3.csv")

# %%
#!pip list

# %%
ithaca_data
# Out:
#    %Daily precip at Ithaca NY for Jan 1987     Unnamed: 1    Unnamed: 2  \
# 0                                  Column1        Column2       Column3
# 1                                      day  precip (inch)  tmin (deg F)
# 2                                   1.0000              0            19
# 3                                   2.0000           0.07            25
# 4                                   3.0000           1.11            22
# 5                                   4.0000              0            -1
# 6                                   5.0000              0             4
# 7                                   6.0000              0            14
# 8                                   7.0000              0            21
# 9                                   8.0000           0.04            22
# 10                                  9.0000           0.02            23
# 11                                 10.0000           0.05            27
# ...

# %%
ithaca_data.shape
# Out:
# (33, 4)

# %% [markdown]
# There are four columns to the file and some numebr of rows (36), there is one varibale stored in my workspace and it is the pandas objec tthat I have assigned to the .csv table "ithaca3.csv" the actualy object is named "ithaca_data"
#
# The table is 33 x 4 which mean that is has 33 rows and 4 columns. the rows are umbered 0-32 since python is indexed at zero. 31 of the 33 rows hold floats since the table is a daily record of temperature at a weather station in Ithaca, NY.

# %%
### create a wet days variable:

wet_ones = ithaca_data["unnamed: 1" == float]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-1745a06475dd> in <module>
# ...
