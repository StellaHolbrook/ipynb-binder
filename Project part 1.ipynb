# %%
import numpy as np

# %%
data1a = np.load("part1a.npz")

# %%
data1b = np.load("part1b.npz")

# %%
print(data1a.files)

print('break')

print(data1b.files)
# Out:
# ['N', 'Svc_0_pmf', 'Lc', 'Ic_0', 'gamma']
# break
# ['N', 'Lc', 'Ic_0', 'gamma', 'L_validation', 'L_test', 'betas_validation']

# %%
# print out attributes of data
print(data1a['N'])          # = entire population
print(data1a['Svc_0_pmf'])  # = vunerable segments in population "s" susceptible
print(data1a['Lc'])         # = viral load density
print(data1a['Ic_0'])       # = infected population at start? 
print(data1a['gamma'])      # = gamma is a constant

#print(sum(data1a["Svc_0_pmf"]))    # this sums to 1 so that summation(v,c) = S

# %%
#attributes for data1b
print(data1b['N'])                # = entire population
print(data1b['Lc'])               # = viral load density
print(data1b['Ic_0'])             # = infected population at start? 
print(data1b['gamma'])            # = gamma is a constant
print(data1b['L_validation'])     # = validation data
print(data1b['L_test'])           # = test data
print(data1b['betas_validation']) # = validation data for betas
# Out:
# 50000.0
# [0.3 0.4 0.7 1. ]
# [[47 90 51 65]
#  [82 31 64 86]
#  [30 66 39 47]
#  [59 26 77 38]
#  [20 63 70 15]
#  [35 31 78 11]
#  [50 55 93 26]
#  [17 89 65 25]
#  [70 27 66 97]
#  [20 18 32 31]
#  [76 13 61 15]
#  [86 48 36 89]
#  [96 15 44 71]
#  [81 53 19 36]
#  [29 44 99 36]
#  [25 34 16 28]
#  [23 84 71 31]
#  [91 70 90 90]
#  [32 11 68 81]
#  [34 37 48 41]]
# 0.07142857142857142
# [[  151.15723798   157.09236032   166.0663423    175.26894184
#     187.12271809   200.29536627   207.19011153   220.23944915
#     235.52590645   247.09469931   263.51055631   281.18896107
#     304.53407513   316.7776232    337.4146583    359.08603642
#     376.95873111   410.63777058   432.23666001   466.32640805]
#  [  168.20103748   175.31698233   184.41546073   191.23318015
#     200.38958258   212.84378649   222.09570163   237.44506788
#     251.13497681   263.20329764   281.12505942   299.02683147
#     312.07088043   336.08191882   353.17466265   372.3214408
# ...

# %% [markdown]
# ![proj190dd.PNG](attachment:proj190dd.PNG)

# %%
### impleting this equation into python code:

beta = [.2, .4, .6, .8, .99]   

# beta will be found using grid search in part 1b. 
# 1a:  "choose arbitrary Bv,c values between [0,1]
    
Svc = data1a['Svc_0_pmf']
I = data1a['Ic_0']
L = data1a['Lc']

def rateSusceptible(beta, Svc, I, N):
    return

def rateInfected(Svc, I): 
    return

def rateRecovered(I):
    return

def viralLoadP(I, L):
    return

# %% [markdown]
# Using the model dynamics described in the previous section, and all the given and chosen pa-rameters, simulate the behavior of the disease for 120 days for this single leaf node
